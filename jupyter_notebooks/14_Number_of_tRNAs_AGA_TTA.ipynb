# %%
import os
from Bio import SeqIO
import pandas as pd
from tqdm import tqdm

# %%
# Define the base directory
base_dir = '/input/all_genbank/'

# Prepare output data
records = []

# List all genus folders
genus_folders = [folder for folder in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, folder))]

# Count total GenBank files for progress bar
total_files = sum(
    len([f for f in os.listdir(os.path.join(base_dir, genus)) if f.endswith(('.gbff', '.gbk'))])
    for genus in genus_folders
)

# Initialize progress bar
with tqdm(total=total_files, desc="Processing GenBank files") as pbar:
    for genus in genus_folders:
        genus_path = os.path.join(base_dir, genus)
        for file_name in os.listdir(genus_path):
            if file_name.endswith(('.gbff', '.gbk')):
                file_path = os.path.join(genus_path, file_name)
                gcf_id = "_".join(file_name.split("_")[:2])
                for record in SeqIO.parse(file_path, "genbank"):
                    organism = record.annotations.get("organism", "Unknown")
                    aga_count = 0
                    tta_count = 0
                    for feature in record.features:
                        if feature.type == "tRNA" and "anticodon" in feature.qualifiers:
                            anticodon = feature.qualifiers['anticodon'][0]
                            if "seq:tct" in anticodon.lower():  # AGA codon = anticodon 'TCT'
                                aga_count += 1
                            elif "seq:taa" in anticodon.lower():  # TTA codon = anticodon 'TAA'
                                tta_count += 1
                    records.append({
                        "Genus": genus,
                        "Organism": organism,
                        "GCF_ID": gcf_id,
                        "tRNA_AGA": aga_count,
                        "tRNA_TTA": tta_count
                    })
                pbar.update(1)

# Create DataFrame
trna_df = pd.DataFrame(records)
# Out:
# Processing GenBank files:  99%|████████████▉| 1927/1937 [11:13<00:02,  3.65it/s]/Users/annasve/anaconda3/envs/PyWGCNA/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1217: BiopythonParserWarning: Premature end of file in sequence data
#   warnings.warn(
# /Users/annasve/anaconda3/envs/PyWGCNA/lib/python3.11/site-packages/Bio/GenBank/__init__.py:843: BiopythonParserWarning: Expected sequence length 6286261, found 2476670 (NZ_CP085042.1).
#   warnings.warn(
# Processing GenBank files: 100%|█████████████| 1937/1937 [11:15<00:00,  2.87it/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 48
#      45 trna_df = pd.DataFrame(records)
#      47 # Display the result
# ---> 48 import ace_tools as tools; tools.display_dataframe_to_user(name="tRNA Anticodon Counts", dataframe=trna_df)
#
# ModuleNotFoundError: No module named 'ace_tools'

# %%
df_unique = trna_df.groupby(['Genus', 'Organism', 'GCF_ID'], as_index=False)[['tRNA_AGA', 'tRNA_TTA']].max()

# %%
df_unique.to_excel('/Users/annasve/Desktop/data/ncbi_genomes/tRNA_per_strain.xlsx', index = False)

# %%
df_unique.head(50)
# Out:
#                Genus                             Organism           GCF_ID  \
# 0   Actinokineospora                Actinokineospora alba  GCF_004362515.1
# 1   Actinokineospora           Actinokineospora baliensis  GCF_016907695.1
# 2   Actinokineospora        Actinokineospora cianjurensis  GCF_003663795.1
# 3   Actinokineospora          Actinokineospora diospyrosa  GCF_024171925.1
# 4   Actinokineospora          Actinokineospora fastidiosa  GCF_014648415.1
# 5   Actinokineospora         Actinokineospora globicatena  GCF_030268905.1
# 6   Actinokineospora         Actinokineospora globicatena  GCF_030268945.1
# 7   Actinokineospora             Actinokineospora iranica  GCF_900101685.1
# 8   Actinokineospora       Actinokineospora sp. UTMC 2448  GCF_024760565.1
# 9   Actinokineospora     Actinokineospora spheciospongiae  GCF_003182415.1
# 10  Actinokineospora              Actinokineospora terrae  GCF_900111175.1
# 11     Amycolatopsis            Amycolatopsis aidingensis  GCF_018885265.1
# 12     Amycolatopsis         Amycolatopsis alba DSM 44262  GCF_000384215.1
# 13     Amycolatopsis                  Amycolatopsis arida  GCF_004365925.1
# 14     Amycolatopsis          Amycolatopsis australiensis  GCF_900119165.1
# 15     Amycolatopsis              Amycolatopsis bartoniae  GCF_014191255.1
# 16     Amycolatopsis        Amycolatopsis cihanbeyliensis  GCF_006715045.1
# 17     Amycolatopsis           Amycolatopsis echigonensis  GCF_002846615.1
# 18     Amycolatopsis              Amycolatopsis granulosa  GCF_011758745.1
# 19     Amycolatopsis           Amycolatopsis jiangsuensis  GCF_014204865.1
# 20     Amycolatopsis          Amycolatopsis keratiniphila  GCF_000400635.2
# 21     Amycolatopsis         Amycolatopsis lexingtonensis  GCF_014873755.1
# 22     Amycolatopsis             Amycolatopsis magusensis  GCF_017875555.1
# 23     Amycolatopsis      Amycolatopsis mediterranei S699  GCF_000282715.1
# 24     Amycolatopsis        Amycolatopsis methanolica 239  GCF_000371885.1
# 25     Amycolatopsis           Amycolatopsis mongoliensis  GCF_030285665.1
# 26     Amycolatopsis  Amycolatopsis nigrescens CSC17Ta-90  GCF_000384315.1
# 27     Amycolatopsis             Amycolatopsis orientalis  GCF_000943515.2
# 28     Amycolatopsis              Amycolatopsis plumensis  GCF_042652605.1
# 29     Amycolatopsis           Amycolatopsis rhabdoformis  GCF_035918295.1
# 30     Amycolatopsis        Amycolatopsis roodepoortensis  GCF_014873915.1
# 31     Amycolatopsis        Amycolatopsis roodepoortensis  GCF_024628825.1
# 32     Amycolatopsis                 Amycolatopsis rubida  GCF_900115345.1
# 33     Amycolatopsis                 Amycolatopsis solani  GCF_033441515.1
# 34     Amycolatopsis           Amycolatopsis sp. 195334CR  GCF_017309385.1
# 35     Amycolatopsis               Amycolatopsis sp. 2-15  GCF_030285625.1
# 36     Amycolatopsis                Amycolatopsis sp. 2-2  GCF_030264295.1
# 37     Amycolatopsis          Amycolatopsis sp. CA-230715  GCF_018736145.1
# 38     Amycolatopsis            Amycolatopsis sp. CB00013  GCF_001905755.1
# 39     Amycolatopsis           Amycolatopsis sp. DG1A-15b  GCF_030285645.1
# 40     Amycolatopsis         Amycolatopsis sp. DSM 110486  GCF_019468465.1
# 41     Amycolatopsis      Amycolatopsis sp. FDAARGOS 1241  GCF_016889705.1
# 42     Amycolatopsis                Amycolatopsis sp. GM8  GCF_021653975.1
# 43     Amycolatopsis          Amycolatopsis sp. HUAS 11-8  GCF_026802195.1
# 44     Amycolatopsis               Amycolatopsis sp. Hca4  GCF_013364075.1
# 45     Amycolatopsis            Amycolatopsis sp. MJM2582  GCF_000754115.1
# 46     Amycolatopsis          Amycolatopsis sp. NBC_00355  GCF_036104975.1
# 47     Amycolatopsis          Amycolatopsis sp. NBC_00438  GCF_036026695.1
# 48     Amycolatopsis          Amycolatopsis sp. NBC_01286  GCF_035982555.1
# 49     Amycolatopsis        Amycolatopsis sp. NBRC 101858  GCF_030269325.1
#
#     tRNA_AGA  tRNA_TTA
# 0          1         1
# 1          1         1
# 2          1         1
# 3          1         1
# 4          1         1
# 5          1         1
# 6          1         1
# 7          1         1
# 8          1         1
# 9          1         1
# 10         1         1
# 11         1         1
# 12         1         1
# 13         1         1
# 14         1         1
# 15         1         1
# 16         1         1
# 17         1         1
# 18         1         1
# 19         1         1
# 20         1         1
# 21         1         1
# 22         1         1
# 23         1         1
# 24         1         1
# 25         1         1
# 26         1         1
# 27         1         1
# 28         1         1
# 29         1         1
# 30         1         1
# 31         1         1
# 32         1         1
# 33         1         1
# 34         1         1
# 35         1         1
# 36         1         1
# 37         1         1
# 38         1         1
# 39         1         1
# 40         1         1
# 41         1         1
# 42         1         1
# 43         1         1
# 44         1         1
# 45         1         1
# 46         1         1
# 47         1         1
# 48         1         1
# 49         1         1
